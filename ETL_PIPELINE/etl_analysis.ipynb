# %%
# !pip install supabase
# !pip install pandas
# !pip install dotenv
# Out:
# Requirement already satisfied: supabase in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (2.25.0)
# Requirement already satisfied: realtime==2.25.0 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from supabase) (2.25.0)
# Requirement already satisfied: supabase-functions==2.25.0 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from supabase) (2.25.0)
# Requirement already satisfied: storage3==2.25.0 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from supabase) (2.25.0)
# Requirement already satisfied: supabase-auth==2.25.0 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from supabase) (2.25.0)
# Requirement already satisfied: postgrest==2.25.0 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from supabase) (2.25.0)
# Requirement already satisfied: httpx<0.29,>=0.26 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from supabase) (0.28.1)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from postgrest==2.25.0->supabase) (2.1.0)
# Requirement already satisfied: pydantic<3.0,>=1.9 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from postgrest==2.25.0->supabase) (2.12.5)
# Requirement already satisfied: yarl>=1.20.1 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from postgrest==2.25.0->supabase) (1.22.0)
# Requirement already satisfied: typing-extensions>=4.14.0 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from realtime==2.25.0->supabase) (4.15.0)
# Requirement already satisfied: websockets<16,>=11 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from realtime==2.25.0->supabase) (15.0.1)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase) (2.10.1)
# Requirement already satisfied: strenum>=0.4.15 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from supabase-functions==2.25.0->supabase) (0.4.15)
# Requirement already satisfied: anyio in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from httpx<0.29,>=0.26->supabase) (4.12.0)
# Requirement already satisfied: certifi in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from httpx<0.29,>=0.26->supabase) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from httpx<0.29,>=0.26->supabase) (1.0.9)
# Requirement already satisfied: idna in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from httpx<0.29,>=0.26->supabase) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from httpx[http2]<0.29,>=0.26->postgrest==2.25.0->supabase) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.25.0->supabase) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.25.0->supabase) (4.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from pydantic<3.0,>=1.9->postgrest==2.25.0->supabase) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from pydantic<3.0,>=1.9->postgrest==2.25.0->supabase) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from pydantic<3.0,>=1.9->postgrest==2.25.0->supabase) (0.4.2)
# Requirement already satisfied: packaging in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from deprecation>=2.1.0->postgrest==2.25.0->supabase) (25.0)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase) (2.23)
# Requirement already satisfied: multidict>=4.0 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from yarl>=1.20.1->postgrest==2.25.0->supabase) (6.7.0)
# Requirement already satisfied: propcache>=0.2.1 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from yarl>=1.20.1->postgrest==2.25.0->supabase) (0.4.1)
# Requirement already satisfied: pandas in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jyothi murali\desktop\tekworks\etl_pipeline\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Collecting python-dotenv (from dotenv)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Installing collected packages: python-dotenv, dotenv
#
#    ---------------------------------------- 0/2 [python-dotenv]
#    ---------------------------------------- 0/2 [python-dotenv]
#    ---------------------------------------- 0/2 [python-dotenv]
#    ---------------------------------------- 2/2 [dotenv]
#
# Successfully installed dotenv-0.9.9 python-dotenv-1.2.1

# %%
from supabase import create_client
import pandas as pd,os 
from dotenv import load_dotenv
load_dotenv()
supabase=create_client(os.getenv("SUPABASE_URL"),os.getenv("SUPABASE_KEY"))
data=supabase.table("titanic_data").select("*").execute()
df=pd.DataFrame(data.data)
df.head()
df.tail()
df.info()
df.isnull().sum()
df.describe()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   sex          891 non-null    object
#  4   age          891 non-null    float64
#  5   sibsp        891 non-null    int64
#  6   parch        891 non-null    int64
#  7   fare         891 non-null    float64
#  8   embarked     891 non-null    object
#  9   class        891 non-null    object
#  10  who          891 non-null    object
#  11  deck         891 non-null    object
#  12  embark_town  889 non-null    object
#  13  alone        891 non-null    bool
#  14  family_size  891 non-null    int64
#  15  is_alone     891 non-null    bool
#  16  title        891 non-null    object
# dtypes: bool(2), float64(2), int64(6), object(7)
# memory usage: 106.3+ KB
# Index(['id', 'survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'deck', 'embark_town', 'alone',
#        'family_size', 'is_alone', 'title'],
#       dtype='object')
